# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 759

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bd36c43c91d8> in <module>
#       1 # Starting URL for Weather Map API Call.
# ----> 2 url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#       3 print(url)
#
# NameError: name 'weather_api_key' is not defined

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | manono
# Processing Record 2 of Set 1 | marsa matruh
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | bodden town
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | nome
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | muisne
# Processing Record 20 of Set 1 | arcata
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | pisco
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | raudeberg
# Processing Record 26 of Set 1 | beringovskiy
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | imbituba
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | bastia
# Processing Record 31 of Set 1 | tiarei
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | dingle
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | wenshang
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | paamiut
# Processing Record 38 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | baruun-urt
# Processing Record 41 of Set 1 | flin flon
# Processing Record 42 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 1 | cockburn town
# Processing Record 48 of Set 1 | revuca
# Processing Record 49 of Set 1 | grindavik
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | gat
# Processing Record 3 of Set 2 | araouane
# Processing Record 4 of Set 2 | moerai
# Processing Record 5 of Set 2 | tateyama
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | tulsipur
# Processing Record 9 of Set 2 | high level
# Processing Record 10 of Set 2 | vernon
# Processing Record 11 of Set 2 | lompoc
# Processing Record 12 of Set 2 | nuuk
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | puerto escondido
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | fivizzano
# Processing Record 18 of Set 2 | barra patuca
# Processing Record 19 of Set 2 | anadyr
# Processing Record 20 of Set 2 | manokwari
# Processing Record 21 of Set 2 | fairbanks
# Processing Record 22 of Set 2 | esperance
# Processing Record 23 of Set 2 | adrar
# Processing Record 24 of Set 2 | la romana
# Processing Record 25 of Set 2 | belyy yar
# Processing Record 26 of Set 2 | ketchikan
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | elko
# Processing Record 29 of Set 2 | ezerelis
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | panjakent
# Processing Record 32 of Set 2 | norman wells
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | mayumba
# Processing Record 35 of Set 2 | young
# Processing Record 36 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 2 | paducah
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | vanimo
# Processing Record 41 of Set 2 | ocampo
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | fare
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | livingston
# Processing Record 46 of Set 2 | traverse city
# Processing Record 47 of Set 2 | kota belud
# Processing Record 48 of Set 2 | atagay
# Processing Record 49 of Set 2 | logan
# Processing Record 50 of Set 2 | mahibadhoo
# Processing Record 1 of Set 3 | puerto ayora
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | manakara
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | singapore
# Processing Record 7 of Set 3 | puerto del rosario
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | tecoanapa
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | palauig
# Processing Record 14 of Set 3 | klaksvik
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | labuhan
# Processing Record 18 of Set 3 | mutsu
# Processing Record 19 of Set 3 | tuktoyaktuk
# Processing Record 20 of Set 3 | aloleng
# Processing Record 21 of Set 3 | orlik
# Processing Record 22 of Set 3 | tamazulapam
# City not found. Skipping...
# Processing Record 23 of Set 3 | iqaluit
# Processing Record 24 of Set 3 | sabha
# Processing Record 25 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | nago
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | shimoda
# Processing Record 29 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 30 of Set 3 | ukiah
# Processing Record 31 of Set 3 | kamenka
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | cumra
# Processing Record 34 of Set 3 | santa ana
# Processing Record 35 of Set 3 | kralendijk
# Processing Record 36 of Set 3 | verkhoyansk
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | zarubino
# Processing Record 39 of Set 3 | quatre cocos
# Processing Record 40 of Set 3 | ak-dovurak
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | haines junction
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | oyem
# Processing Record 45 of Set 3 | mpanda
# Processing Record 46 of Set 3 | sovetskiy
# Processing Record 47 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 3 | vostok
# Processing Record 49 of Set 3 | vakhrushev
# Processing Record 50 of Set 3 | orcopampa
# Processing Record 1 of Set 4 | laguna
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | batemans bay
# Processing Record 5 of Set 4 | san luis
# Processing Record 6 of Set 4 | baykit
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | swan river
# Processing Record 11 of Set 4 | nova londrina
# Processing Record 12 of Set 4 | handwara
# City not found. Skipping...
# Processing Record 13 of Set 4 | ponta delgada
# Processing Record 14 of Set 4 | tual
# Processing Record 15 of Set 4 | mareeba
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | marsaxlokk
# Processing Record 18 of Set 4 | dalnerechensk
# Processing Record 19 of Set 4 | luau
# Processing Record 20 of Set 4 | yar-sale
# Processing Record 21 of Set 4 | hilo
# Processing Record 22 of Set 4 | port-gentil
# Processing Record 23 of Set 4 | gorontalo
# Processing Record 24 of Set 4 | rudolstadt
# Processing Record 25 of Set 4 | bara
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | samarai
# Processing Record 28 of Set 4 | saint-philippe
# Processing Record 29 of Set 4 | mitu
# Processing Record 30 of Set 4 | vao
# Processing Record 31 of Set 4 | behbahan
# Processing Record 32 of Set 4 | tomatlan
# Processing Record 33 of Set 4 | eureka
# Processing Record 34 of Set 4 | te anau
# Processing Record 35 of Set 4 | ryotsu
# Processing Record 36 of Set 4 | kintampo
# Processing Record 37 of Set 4 | palana
# Processing Record 38 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 4 | lasa
# Processing Record 40 of Set 4 | vilyuysk
# Processing Record 41 of Set 4 | reconquista
# Processing Record 42 of Set 4 | belmonte
# Processing Record 43 of Set 4 | pagman
# City not found. Skipping...
# Processing Record 44 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 4 | valentin gomez farias
# Processing Record 46 of Set 4 | praia da vitoria
# Processing Record 47 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | qaanaaq
# Processing Record 50 of Set 4 | hasaki
# Processing Record 1 of Set 5 | taoudenni
# Processing Record 2 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 5 | santiago del estero
# Processing Record 4 of Set 5 | kutum
# Processing Record 5 of Set 5 | jamestown
# Processing Record 6 of Set 5 | dunedin
# Processing Record 7 of Set 5 | port lincoln
# Processing Record 8 of Set 5 | khatanga
# Processing Record 9 of Set 5 | buritizeiro
# Processing Record 10 of Set 5 | beloha
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | chunoyar
# Processing Record 13 of Set 5 | christchurch
# Processing Record 14 of Set 5 | turukhansk
# Processing Record 15 of Set 5 | marfino
# Processing Record 16 of Set 5 | maramba
# Processing Record 17 of Set 5 | sioux lookout
# Processing Record 18 of Set 5 | katete
# Processing Record 19 of Set 5 | kalmunai
# Processing Record 20 of Set 5 | kirakira
# Processing Record 21 of Set 5 | sosva
# Processing Record 22 of Set 5 | constantine
# Processing Record 23 of Set 5 | bay roberts
# Processing Record 24 of Set 5 | severnyy
# Processing Record 25 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 5 | korla
# Processing Record 27 of Set 5 | kot diji
# Processing Record 28 of Set 5 | shenjiamen
# Processing Record 29 of Set 5 | sistranda
# Processing Record 30 of Set 5 | lerwick
# Processing Record 31 of Set 5 | dikson
# Processing Record 32 of Set 5 | hongan
# City not found. Skipping...
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | burnie
# Processing Record 35 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 5 | oleksandrivka
# Processing Record 37 of Set 5 | bandarbeyla
# Processing Record 38 of Set 5 | akyab
# Processing Record 39 of Set 5 | jackson
# Processing Record 40 of Set 5 | atambua
# Processing Record 41 of Set 5 | craig
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | buzmeyin
# Processing Record 44 of Set 5 | chunskiy
# Processing Record 45 of Set 5 | darnah
# Processing Record 46 of Set 5 | broome
# Processing Record 47 of Set 5 | gladstone
# Processing Record 48 of Set 5 | batagay
# Processing Record 49 of Set 5 | yulara
# Processing Record 50 of Set 5 | bambanglipuro
# Processing Record 1 of Set 6 | shaki
# Processing Record 2 of Set 6 | padang
# Processing Record 3 of Set 6 | vuktyl
# Processing Record 4 of Set 6 | hobyo
# Processing Record 5 of Set 6 | sanchursk
# Processing Record 6 of Set 6 | rognan
# Processing Record 7 of Set 6 | margate
# Processing Record 8 of Set 6 | todos santos
# Processing Record 9 of Set 6 | manadhoo
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 6 | shwebo
# Processing Record 13 of Set 6 | ivanovskaya
# Processing Record 14 of Set 6 | umarkot
# Processing Record 15 of Set 6 | balsas
# Processing Record 16 of Set 6 | qasigiannguit
# Processing Record 17 of Set 6 | thompson
# Processing Record 18 of Set 6 | hamilton
# Processing Record 19 of Set 6 | ribeira grande
# Processing Record 20 of Set 6 | vlissingen
# Processing Record 21 of Set 6 | amapa
# Processing Record 22 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | salalah
# Processing Record 24 of Set 6 | jalu
# Processing Record 25 of Set 6 | horqueta
# Processing Record 26 of Set 6 | walvis bay
# Processing Record 27 of Set 6 | camacha
# Processing Record 28 of Set 6 | kendari
# Processing Record 29 of Set 6 | lorengau
# Processing Record 30 of Set 6 | bjornevatn
# Processing Record 31 of Set 6 | dudinka
# Processing Record 32 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 33 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 6 | bathsheba
# Processing Record 36 of Set 6 | rusera
# Processing Record 37 of Set 6 | madimba
# Processing Record 38 of Set 6 | yurimaguas
# Processing Record 39 of Set 6 | zemio
# Processing Record 40 of Set 6 | jhanjharpur
# Processing Record 41 of Set 6 | brae
# Processing Record 42 of Set 6 | tiksi
# Processing Record 43 of Set 6 | bredasdorp
# Processing Record 44 of Set 6 | kenora
# Processing Record 45 of Set 6 | yakima
# Processing Record 46 of Set 6 | provideniya
# Processing Record 47 of Set 6 | tautira
# Processing Record 48 of Set 6 | puerto baquerizo moreno
# Processing Record 49 of Set 6 | merrill
# Processing Record 50 of Set 6 | zhanaozen
# Processing Record 1 of Set 7 | parkersburg
# Processing Record 2 of Set 7 | udachnyy
# Processing Record 3 of Set 7 | roald
# Processing Record 4 of Set 7 | danielskuil
# Processing Record 5 of Set 7 | san andres
# Processing Record 6 of Set 7 | orapa
# Processing Record 7 of Set 7 | inhambane
# Processing Record 8 of Set 7 | hami
# Processing Record 9 of Set 7 | pali
# Processing Record 10 of Set 7 | alofi
# Processing Record 11 of Set 7 | okhotsk
# Processing Record 12 of Set 7 | cotonou
# Processing Record 13 of Set 7 | madaoua
# Processing Record 14 of Set 7 | belawan
# Processing Record 15 of Set 7 | buchanan
# Processing Record 16 of Set 7 | staryy nadym
# Processing Record 17 of Set 7 | leningradskiy
# Processing Record 18 of Set 7 | skjervoy
# Processing Record 19 of Set 7 | goose creek
# Processing Record 20 of Set 7 | bontang
# Processing Record 21 of Set 7 | wewak
# Processing Record 22 of Set 7 | ulladulla
# Processing Record 23 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 7 | boljevac
# Processing Record 25 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 26 of Set 7 | fort saint james
# Processing Record 27 of Set 7 | luderitz
# Processing Record 28 of Set 7 | barentu
# Processing Record 29 of Set 7 | saint-augustin
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | sevierville
# Processing Record 32 of Set 7 | khartoum
# Processing Record 33 of Set 7 | bonito
# Processing Record 34 of Set 7 | pittsfield
# Processing Record 35 of Set 7 | russell
# Processing Record 36 of Set 7 | waipawa
# Processing Record 37 of Set 7 | goba
# Processing Record 38 of Set 7 | avera
# Processing Record 39 of Set 7 | inuvik
# Processing Record 40 of Set 7 | najran
# Processing Record 41 of Set 7 | ushtobe
# Processing Record 42 of Set 7 | port macquarie
# Processing Record 43 of Set 7 | atasu
# Processing Record 44 of Set 7 | constitucion
# Processing Record 45 of Set 7 | rawlins
# Processing Record 46 of Set 7 | buala
# Processing Record 47 of Set 7 | sitges
# Processing Record 48 of Set 7 | sakakah
# Processing Record 49 of Set 7 | ossora
# Processing Record 50 of Set 7 | kaduy
# Processing Record 1 of Set 8 | derzhavinsk
# Processing Record 2 of Set 8 | pingliang
# Processing Record 3 of Set 8 | cherskiy
# Processing Record 4 of Set 8 | benavente
# Processing Record 5 of Set 8 | olinda
# Processing Record 6 of Set 8 | tura
# Processing Record 7 of Set 8 | nalut
# Processing Record 8 of Set 8 | sturgeon bay
# Processing Record 9 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 8 | le locle
# Processing Record 11 of Set 8 | caloundra
# Processing Record 12 of Set 8 | boshnyakovo
# Processing Record 13 of Set 8 | puerto narino
# Processing Record 14 of Set 8 | uyuni
# Processing Record 15 of Set 8 | yingcheng
# Processing Record 16 of Set 8 | mount gambier
# Processing Record 17 of Set 8 | uri
# Processing Record 18 of Set 8 | marquette
# Processing Record 19 of Set 8 | popondetta
# Processing Record 20 of Set 8 | sao miguel do araguaia
# Processing Record 21 of Set 8 | rocha
# Processing Record 22 of Set 8 | broken hill
# Processing Record 23 of Set 8 | vagur
# Processing Record 24 of Set 8 | burgeo
# Processing Record 25 of Set 8 | bambous virieux
# Processing Record 26 of Set 8 | cidreira
# Processing Record 27 of Set 8 | astoria
# Processing Record 28 of Set 8 | collingwood
# Processing Record 29 of Set 8 | liverpool
# Processing Record 30 of Set 8 | penzance
# Processing Record 31 of Set 8 | las choapas
# Processing Record 32 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 8 | henties bay
# Processing Record 34 of Set 8 | kenai
# Processing Record 35 of Set 8 | kavaratti
# Processing Record 36 of Set 8 | vestmannaeyjar
# Processing Record 37 of Set 8 | marsh harbour
# Processing Record 38 of Set 8 | lagoa
# Processing Record 39 of Set 8 | brunico
# Processing Record 40 of Set 8 | mitchell
# Processing Record 41 of Set 8 | vila franca do campo
# Processing Record 42 of Set 8 | ouagadougou
# Processing Record 43 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 8 | macau
# Processing Record 45 of Set 8 | shingu
# Processing Record 46 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 8 | isangel
# Processing Record 48 of Set 8 | geilo
# Processing Record 49 of Set 8 | guerrero negro
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | malatya
# Processing Record 2 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 3 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 4 of Set 9 | sao joao da barra
# Processing Record 5 of Set 9 | vila do maio
# Processing Record 6 of Set 9 | lucapa
# Processing Record 7 of Set 9 | uribia
# Processing Record 8 of Set 9 | tamandare
# Processing Record 9 of Set 9 | vardo
# Processing Record 10 of Set 9 | richards bay
# Processing Record 11 of Set 9 | leshukonskoye
# Processing Record 12 of Set 9 | martapura
# Processing Record 13 of Set 9 | tilichiki
# Processing Record 14 of Set 9 | leeton
# Processing Record 15 of Set 9 | namibe
# Processing Record 16 of Set 9 | codrington
# Processing Record 17 of Set 9 | changji
# Processing Record 18 of Set 9 | of
# City not found. Skipping...
# Processing Record 19 of Set 9 | ostrovnoy
# Processing Record 20 of Set 9 | hongjiang
# Processing Record 21 of Set 9 | puerto quijarro
# Processing Record 22 of Set 9 | aswan
# Processing Record 23 of Set 9 | porto velho
# Processing Record 24 of Set 9 | basoko
# Processing Record 25 of Set 9 | college
# Processing Record 26 of Set 9 | wau
# Processing Record 27 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 9 | zhuhai
# Processing Record 29 of Set 9 | tucuman
# Processing Record 30 of Set 9 | muros
# Processing Record 31 of Set 9 | chichi
# Processing Record 32 of Set 9 | nongan
# Processing Record 33 of Set 9 | rudnichnyy
# Processing Record 34 of Set 9 | faanui
# Processing Record 35 of Set 9 | casimcea
# Processing Record 36 of Set 9 | portland
# Processing Record 37 of Set 9 | ugoofaaru
# Processing Record 38 of Set 9 | san cristobal
# Processing Record 39 of Set 9 | northam
# Processing Record 40 of Set 9 | kapit
# Processing Record 41 of Set 9 | platteville
# Processing Record 42 of Set 9 | acapulco
# Processing Record 43 of Set 9 | dapdap
# Processing Record 44 of Set 9 | praia
# Processing Record 45 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 9 | altay
# Processing Record 47 of Set 9 | rockhampton
# Processing Record 48 of Set 9 | bilma
# Processing Record 49 of Set 9 | tombouctou
# Processing Record 50 of Set 9 | gondar
# Processing Record 1 of Set 10 | stephenville
# Processing Record 2 of Set 10 | sibolga
# Processing Record 3 of Set 10 | caravelas
# Processing Record 4 of Set 10 | komsomolskiy
# Processing Record 5 of Set 10 | awjilah
# Processing Record 6 of Set 10 | mehamn
# Processing Record 7 of Set 10 | kuusamo
# Processing Record 8 of Set 10 | honningsvag
# Processing Record 9 of Set 10 | villamontes
# Processing Record 10 of Set 10 | ola
# Processing Record 11 of Set 10 | nuevitas
# Processing Record 12 of Set 10 | waingapu
# Processing Record 13 of Set 10 | denpasar
# Processing Record 14 of Set 10 | zabol
# Processing Record 15 of Set 10 | kungurtug
# Processing Record 16 of Set 10 | ancud
# Processing Record 17 of Set 10 | bayan
# Processing Record 18 of Set 10 | esqueda
# Processing Record 19 of Set 10 | takaka
# Processing Record 20 of Set 10 | nurota
# Processing Record 21 of Set 10 | safaga
# Processing Record 22 of Set 10 | saint-francois
# Processing Record 23 of Set 10 | faya
# Processing Record 24 of Set 10 | nombre de dios
# Processing Record 25 of Set 10 | mitsamiouli
# Processing Record 26 of Set 10 | coquimbo
# Processing Record 27 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 10 | meulaboh
# Processing Record 29 of Set 10 | alice springs
# Processing Record 30 of Set 10 | lokosovo
# Processing Record 31 of Set 10 | lynchburg
# Processing Record 32 of Set 10 | westport
# Processing Record 33 of Set 10 | urengoy
# Processing Record 34 of Set 10 | guane
# Processing Record 35 of Set 10 | mongoumba
# Processing Record 36 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | mnogovershinnyy
# Processing Record 38 of Set 10 | valsad
# Processing Record 39 of Set 10 | qaqortoq
# Processing Record 40 of Set 10 | illapel
# Processing Record 41 of Set 10 | marawi
# Processing Record 42 of Set 10 | chivay
# Processing Record 43 of Set 10 | daru
# Processing Record 44 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 10 | ifanadiana
# Processing Record 46 of Set 10 | zhigalovo
# Processing Record 47 of Set 10 | warud
# Processing Record 48 of Set 10 | ust-kulom
# Processing Record 49 of Set 10 | rio grande
# Processing Record 50 of Set 10 | balabac
# Processing Record 1 of Set 11 | miandrivazo
# Processing Record 2 of Set 11 | datong
# Processing Record 3 of Set 11 | montabaur
# Processing Record 4 of Set 11 | bolotnoye
# Processing Record 5 of Set 11 | evensk
# Processing Record 6 of Set 11 | orje
# Processing Record 7 of Set 11 | menongue
# Processing Record 8 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 11 | chiang mai
# Processing Record 11 of Set 11 | genhe
# Processing Record 12 of Set 11 | guiratinga
# Processing Record 13 of Set 11 | lunenburg
# Processing Record 14 of Set 11 | krasnorechenskiy
# Processing Record 15 of Set 11 | palmer
# Processing Record 16 of Set 11 | san angelo
# Processing Record 17 of Set 11 | lazaro cardenas
# Processing Record 18 of Set 11 | kudahuvadhoo
# Processing Record 19 of Set 11 | takoradi
# Processing Record 20 of Set 11 | fortuna
# Processing Record 21 of Set 11 | santa isabel
# Processing Record 22 of Set 11 | cieza
# Processing Record 23 of Set 11 | cumpas
# Processing Record 24 of Set 11 | goderich
# Processing Record 25 of Set 11 | kachiry
# Processing Record 26 of Set 11 | port hardy
# Processing Record 27 of Set 11 | ronchi dei legionari
# Processing Record 28 of Set 11 | bireun
# Processing Record 29 of Set 11 | huaicheng
# Processing Record 30 of Set 11 | villeneuve-sur-lot
# Processing Record 31 of Set 11 | jumla
# Processing Record 32 of Set 11 | koungou
# Processing Record 33 of Set 11 | kahului
# Processing Record 34 of Set 11 | viedma
# Processing Record 35 of Set 11 | dolores
# Processing Record 36 of Set 11 | innisfail
# Processing Record 37 of Set 11 | ahipara
# Processing Record 38 of Set 11 | kotlas
# Processing Record 39 of Set 11 | bentiu
# Processing Record 40 of Set 11 | clyde river
# Processing Record 41 of Set 11 | port blair
# Processing Record 42 of Set 11 | san patricio
# Processing Record 43 of Set 11 | ust-tsilma
# Processing Record 44 of Set 11 | gazojak
# Processing Record 45 of Set 11 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 46 of Set 11 | saint-prosper
# Processing Record 47 of Set 11 | cayenne
# Processing Record 48 of Set 11 | edgewater
# Processing Record 49 of Set 11 | ombessa
# Processing Record 50 of Set 11 | mochalishche
# Processing Record 1 of Set 12 | blagoyevo
# Processing Record 2 of Set 12 | sassandra
# Processing Record 3 of Set 12 | sfantu gheorghe
# Processing Record 4 of Set 12 | dali
# Processing Record 5 of Set 12 | sobolevo
# Processing Record 6 of Set 12 | ambilobe
# Processing Record 7 of Set 12 | krasnoselkup
# Processing Record 8 of Set 12 | massaranduba
# Processing Record 9 of Set 12 | alihe
# Processing Record 10 of Set 12 | okitipupa
# Processing Record 11 of Set 12 | ust-nera
# Processing Record 12 of Set 12 | neumunster
# Processing Record 13 of Set 12 | north battleford
# Processing Record 14 of Set 12 | khash
# Processing Record 15 of Set 12 | bartlesville
# Processing Record 16 of Set 12 | balikpapan
# Processing Record 17 of Set 12 | betong
# Processing Record 18 of Set 12 | cairns
# Processing Record 19 of Set 12 | platanos
# Processing Record 20 of Set 12 | salinopolis
# Processing Record 21 of Set 12 | necochea
# Processing Record 22 of Set 12 | aykhal
# Processing Record 23 of Set 12 | hambantota
# Processing Record 24 of Set 12 | souillac
# Processing Record 25 of Set 12 | lannion
# Processing Record 26 of Set 12 | bubaque
# Processing Record 27 of Set 12 | arys
# Processing Record 28 of Set 12 | korsakovo
# Processing Record 29 of Set 12 | ransang
# Processing Record 30 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 12 | natal
# Processing Record 32 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 33 of Set 12 | maumere
# Processing Record 34 of Set 12 | chabahar
# Processing Record 35 of Set 12 | zaozerne
# Processing Record 36 of Set 12 | cabedelo
# Processing Record 37 of Set 12 | solwezi
# Processing Record 38 of Set 12 | nebbi
# Processing Record 39 of Set 12 | burdur
# Processing Record 40 of Set 12 | karoi
# Processing Record 41 of Set 12 | hvolsvollur
# Processing Record 42 of Set 12 | boende
# Processing Record 43 of Set 12 | west wendover
# Processing Record 44 of Set 12 | seoul
# Processing Record 45 of Set 12 | parakan
# Processing Record 46 of Set 12 | bonga
# Processing Record 47 of Set 12 | vicosa do ceara
# Processing Record 48 of Set 12 | lakatoro
# Processing Record 49 of Set 12 | karymskoye
# Processing Record 50 of Set 12 | katherine
# Processing Record 1 of Set 13 | lata
# Processing Record 2 of Set 13 | la foa
# Processing Record 3 of Set 13 | cap malheureux
# Processing Record 4 of Set 13 | aklavik
# Processing Record 5 of Set 13 | weihe
# Processing Record 6 of Set 13 | paso de los toros
# Processing Record 7 of Set 13 | verkhniye tatyshly
# Processing Record 8 of Set 13 | turayf
# Processing Record 9 of Set 13 | lavrentiya
# Processing Record 10 of Set 13 | tianpeng
# Processing Record 11 of Set 13 | hudson bay
# Processing Record 12 of Set 13 | katobu
# Processing Record 13 of Set 13 | angoche
# Processing Record 14 of Set 13 | plymouth
# Processing Record 15 of Set 13 | dzhebariki-khaya
# Processing Record 16 of Set 13 | palora
# Processing Record 17 of Set 13 | tanhacu
# Processing Record 18 of Set 13 | kropotkin
# Processing Record 19 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 20 of Set 13 | southbridge
# Processing Record 21 of Set 13 | isoka
# Processing Record 22 of Set 13 | karla
# Processing Record 23 of Set 13 | antofagasta
# Processing Record 24 of Set 13 | itarema
# Processing Record 25 of Set 13 | iskateley
# Processing Record 26 of Set 13 | porto novo
# Processing Record 27 of Set 13 | grand gaube
# Processing Record 28 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 29 of Set 13 | hofn
# Processing Record 30 of Set 13 | deputatskiy
# Processing Record 31 of Set 13 | zatoka
# Processing Record 32 of Set 13 | port hedland
# Processing Record 33 of Set 13 | mackay
# Processing Record 34 of Set 13 | olavarria
# Processing Record 35 of Set 13 | wawa
# Processing Record 36 of Set 13 | fort-shevchenko
# Processing Record 37 of Set 13 | maues
# Processing Record 38 of Set 13 | ixtapa
# Processing Record 39 of Set 13 | coihaique
# Processing Record 40 of Set 13 | chifeng
# Processing Record 41 of Set 13 | namatanai
# Processing Record 42 of Set 13 | dauriya
# Processing Record 43 of Set 13 | suntar
# Processing Record 44 of Set 13 | kizema
# Processing Record 45 of Set 13 | gewane
# Processing Record 46 of Set 13 | saint-joseph
# Processing Record 47 of Set 13 | erenhot
# Processing Record 48 of Set 13 | marzuq
# Processing Record 49 of Set 13 | junction city
# Processing Record 50 of Set 13 | narsaq
# Processing Record 1 of Set 14 | jinchang
# Processing Record 2 of Set 14 | tigil
# Processing Record 3 of Set 14 | srednekolymsk
# Processing Record 4 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 14 | kusk
# City not found. Skipping...
# Processing Record 6 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 14 | grand-bourg
# Processing Record 8 of Set 14 | hornepayne
# Processing Record 9 of Set 14 | sankt andra
# City not found. Skipping...
# Processing Record 10 of Set 14 | cumberland
# Processing Record 11 of Set 14 | baiquan
# Processing Record 12 of Set 14 | birao
# Processing Record 13 of Set 14 | sechura
# Processing Record 14 of Set 14 | shizunai
# Processing Record 15 of Set 14 | karratha
# Processing Record 16 of Set 14 | nicolas bravo
# Processing Record 17 of Set 14 | shetpe
# Processing Record 18 of Set 14 | severiano melo
# Processing Record 19 of Set 14 | kanniyakumari
# Processing Record 20 of Set 14 | asosa
# Processing Record 21 of Set 14 | inverness
# Processing Record 22 of Set 14 | ratnagiri
# Processing Record 23 of Set 14 | moose jaw
# Processing Record 24 of Set 14 | chernyshevskiy
# Processing Record 25 of Set 14 | hay river
# Processing Record 26 of Set 14 | krasnyy chikoy
# Processing Record 27 of Set 14 | angoram
# Processing Record 28 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 14 | san rafael del sur
# Processing Record 30 of Set 14 | darfo
# Processing Record 31 of Set 14 | ewa beach
# Processing Record 32 of Set 14 | nishihara
# Processing Record 33 of Set 14 | praya
# Processing Record 34 of Set 14 | kuito
# Processing Record 35 of Set 14 | bilibino
# Processing Record 36 of Set 14 | gamboula
# Processing Record 37 of Set 14 | itupiranga
# Processing Record 38 of Set 14 | caceres
# Processing Record 39 of Set 14 | chajul
# Processing Record 40 of Set 14 | araguacu
# Processing Record 41 of Set 14 | cacu
# Processing Record 42 of Set 14 | nyurba
# Processing Record 43 of Set 14 | ambatofinandrahana
# Processing Record 44 of Set 14 | horki
# Processing Record 45 of Set 14 | niono
# Processing Record 46 of Set 14 | pinega
# Processing Record 47 of Set 14 | catemaco
# Processing Record 48 of Set 14 | kracheh
# City not found. Skipping...
# Processing Record 49 of Set 14 | priboj
# Processing Record 50 of Set 14 | la ronge
# Processing Record 1 of Set 15 | gamba
# Processing Record 2 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 15 | kiama
# Processing Record 4 of Set 15 | goundam
# Processing Record 5 of Set 15 | amahai
# Processing Record 6 of Set 15 | kloulklubed
# Processing Record 7 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 15 | cabo san lucas
# Processing Record 9 of Set 15 | egvekinot
# Processing Record 10 of Set 15 | tres arroyos
# Processing Record 11 of Set 15 | daloa
# Processing Record 12 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 15 | general cepeda
# Processing Record 14 of Set 15 | hokitika
# Processing Record 15 of Set 15 | loudi
# Processing Record 16 of Set 15 | manthani
# Processing Record 17 of Set 15 | burica
# City not found. Skipping...
# Processing Record 18 of Set 15 | san jose
# Processing Record 19 of Set 15 | arman
# Processing Record 20 of Set 15 | shu
# Processing Record 21 of Set 15 | ati
# Processing Record 22 of Set 15 | tezu
# Processing Record 23 of Set 15 | kulevcha
# Processing Record 24 of Set 15 | mantua
# Processing Record 25 of Set 15 | fort nelson
# Processing Record 26 of Set 15 | amga
# Processing Record 27 of Set 15 | athabasca
# Processing Record 28 of Set 15 | geraldton
# Processing Record 29 of Set 15 | guozhen
# Processing Record 30 of Set 15 | hailar
# Processing Record 31 of Set 15 | cortez
# Processing Record 32 of Set 15 | mandalgovi
# Processing Record 33 of Set 15 | sesheke
# Processing Record 34 of Set 15 | tessalit
# Processing Record 35 of Set 15 | port augusta
# Processing Record 36 of Set 15 | juba
# Processing Record 37 of Set 15 | komatsu
# Processing Record 38 of Set 15 | khor
# Processing Record 39 of Set 15 | sola
# Processing Record 40 of Set 15 | palencia
# Processing Record 41 of Set 15 | lanzhou
# Processing Record 42 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 43 of Set 15 | kulykiv
# Processing Record 44 of Set 15 | nemuro
# Processing Record 45 of Set 15 | norden
# Processing Record 46 of Set 15 | ermelo
# Processing Record 47 of Set 15 | aripuana
# Processing Record 48 of Set 15 | pontianak
# Processing Record 49 of Set 15 | eyl
# Processing Record 50 of Set 15 | abha
# Processing Record 1 of Set 16 | pontes e lacerda
# Processing Record 2 of Set 16 | neiafu
# Processing Record 3 of Set 16 | montepuez
# Processing Record 4 of Set 16 | krapina
# Processing Record 5 of Set 16 | puerto ayacucho
# Processing Record 6 of Set 16 | nasrullaganj
# City not found. Skipping...
# Processing Record 7 of Set 16 | cam ranh
# Processing Record 8 of Set 16 | ledyard
# Processing Record 9 of Set 16 | aktash
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Manono      CD  -7.3000   27.4167     67.41        93          93
# 1  Marsa Matruh      EG  31.3525   27.2453     60.80        67          75
# 2       Rikitea      PF -23.1203 -134.9692     77.50        72           3
# 3       Ushuaia      AR -54.8000  -68.3000     46.40        49          20
# 4   Bodden Town      KY  19.2833  -81.2500     82.99        74          20
# 5    Butaritari      KI   3.0707  172.7902     81.97        77          87
# 6  Punta Arenas      CL -53.1500  -70.9167     41.00        70           0
# 7        Albany      US  42.6001  -73.9662     50.00        54          95
# 8         Airai      TL  -8.9266  125.4092     66.52        69          81
# 9     Ilulissat      GL  69.2167  -51.1000     15.80        73          24
#
#    Wind Speed Current Description
# 0        3.80     overcast clouds
# 1       12.66       broken clouds
# 2        3.04           clear sky
# 3        6.91          few clouds
# 4       10.36          few clouds
# 5       18.97          light rain
# 6       12.66           clear sky
# 7        8.30     overcast clouds
# 8        0.76       broken clouds
# 9        5.75          few clouds

# %%
output_data_file = "C:\\Users\johns\Class\World_Weather_Analysis\Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
